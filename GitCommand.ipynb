# %% [markdown]
# # Git Command - Notebook
#
# __*Objectives :*__
#
# The objective of this notebook is too simplify interation with git repository on Google Colab.
#
# ```
# __author__ = "Yohann Lereclus"
# __maintainer__ = "Yohann Lereclus"
# __email__ = "lereclus84L@gmail.com"
# __date__ = "19/11/2019"
# ```
#
# Table of content :
# - Functions
# - Directory change
# - Init repo with gitflow workflow
# - Status
# - Add files
# - commit
# - push

# %% [markdown]
# ## Functions

# %%
user = "yohann84L"
repo_name = "home-assignment-answer"

# %%
def exec_cmd_with_pwd(command, user, repo_name):
  import os
  from getpass import getpass
  import urllib

  password = getpass('Password: ')
  password = urllib.parse.quote(password) # your password is converted into url format


  cmd_string = '{3} https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name, command)

  os.system(cmd_string)
  cmd_string, password = "", "" # removing the password from the variable

# %% [markdown]
# ## Directory change

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/home-assigment-answer")
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/home-assigment-answer

# %% [markdown]
# ## Init repo with gitflow

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/home-assigment-answer/.git/

# %%
# !echo "# home-assignment-answer" >> README.md

# %%
# !git config --global user.email "lereclus84L@gmail.com"

# %%
# !git config --global user.name "Yohann Lereclus"

# %%
# !git add README.md
# !git commit -m "Init commit"
# Out:
# On branch master
# Untracked files:
# 	GitCommand.ipynb
# 	Untitled0.ipynb
# 	assignment_imgs/
# 	img_annotations.json
# 	label_mapping.csv
#
# nothing added to commit but untracked files present

# %%
exec_cmd_with_pwd("git remote add origin", user, repo_name)
# Out:
# Password: ··········

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Writing objects: 100% (3/3), 229 bytes | 114.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/yohann84L/home-assignment-answer.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !apt-get install git-flow
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   git-flow
# 0 upgraded, 1 newly installed, 0 to remove and 29 not upgraded.
# Need to get 38.6 kB of archives.
# After this operation, 327 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 git-flow all 1.11.0-1 [38.6 kB]
# Fetched 38.6 kB in 0s (82.2 kB/s)
# Selecting previously unselected package git-flow.
# (Reading database ... 134923 files and directories currently installed.)
# Preparing to unpack .../git-flow_1.11.0-1_all.deb ...
# Unpacking git-flow (1.11.0-1) ...
# Setting up git-flow (1.11.0-1) ...

# %%
# !git flow init
# Out:
# Which branch should be used for bringing forth production releases?
#    - master
# Branch name for production releases: [master]
# Branch name for "next release" development: [develop]
#
# How to name your supporting branch prefixes?
# Feature branches? [feature/]
# Bugfix branches? [bugfix/]
# Release branches? [release/]
# Hotfix branches? [hotfix/]
# Support branches? [support/]
# Version tag prefix? []
# Hooks and filters directory? [/content/drive/My Drive/Colab Notebooks/home-assigment-answer/.git/hooks]

# %% [markdown]
# ## Check branch

# %%
# !git branch
# Out:
# * develop
#   master

# %% [markdown]
# ## Add files

# %%
import os, os.path

# simple version for working with CWD
list_files = [name for name in os.listdir()]
print("List files:")
for name in list_files:
  print("    - {:s}".format(name))
# Out:
# List files:
#     - GitCommand.ipynb
#     - assignment_imgs
#     - label_mapping.csv
#     - img_annotations.json
#     - Untitled0.ipynb
#     - .git
#     - README.md

# %%
# !git add

# %%
# !git status
# Out:
# On branch develop
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	.gitignore
# 	GitCommand.ipynb
# 	Untitled0.ipynb
# 	img_annotations.json
# 	label_mapping.csv
#
# nothing added to commit but untracked files present (use "git add" to track)
